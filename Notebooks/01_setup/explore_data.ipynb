# %%
# %run ./storage_config

# %%
raw_file_name

# %%
dbutils.fs.ls(raw_folder)
raw_df = spark.read.csv(raw_file_path, header=True, inferSchema=True)

# %%
display(raw_df.limit(100))
