# %%
storage_account = "nstrainprojectstorage"
container_name = "ns-data"

source_folder_name = "source"
source_file_name = 'services-2026-01'
source_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{source_folder}"
source_file_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{source_folder}/{source_file_name}.csv"

raw_folder_name = "raw"
raw_file_name = f'raw-{source_file_name}'
raw_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{raw_folder}"
raw_file_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{raw_folder}/{raw_file_name}"
