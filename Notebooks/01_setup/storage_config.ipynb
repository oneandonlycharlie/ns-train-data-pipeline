# %%
storage_account = "nstrainprojectstorage"
container_name = "ns-data"

source_folder_name = "source"
source_file_name = 'services-2026-01'
source_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{source_folder_name}"
source_file_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{source_folder_name}/{source_file_name}.csv"

raw_folder_name = "raw"
raw_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{raw_folder_name}"

processed_folder_name = "processed"
processed_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{processed_folder_name}"

presentation_folder_name = "presentation"
presentation_folder_path = f"abfss://{container_name}@{storage_account}.dfs.core.windows.net/{presentation_folder_name}"

# config for presentation layer 
presentation_db_name = "presentation"
daily_summary_table = "daily_summaries_by_service"
station_table = "daily_summaries_by_station"
hourly_delay_table = "delays"

# %%
# to do - add schema script
