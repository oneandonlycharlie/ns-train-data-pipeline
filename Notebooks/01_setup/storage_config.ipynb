# %%
schema = "default"
volume_name = "ns_data"

source_folder_name = "source"
source_file_name = 'services-2026-01'
source_folder_path = f'/Volumes/workspace/{schema}/{volume_name}/{source_folder_name}'
source_file_path = f'/Volumes/workspace/{schema}/{volume_name}/{source_folder_name}/{source_file_name}'

raw_folder_name = "raw"
raw_folder_path = f'/Volumes/workspace/{schema}/{volume_name}/{raw_folder_name}/{source_file_name}'

processed_folder_name = "processed"
processed_folder_path = f'/Volumes/workspace/{schema}/{volume_name}/{processed_folder_name}'

presentation_folder_name = "presentation"
presentation_folder_path = f'/Volumes/workspace/{schema}/{volume_name}/{presentation_folder_name}'

# config for presentation layer 
presentation_db_name = "presentation"
daily_summary_table = "daily_summaries_by_service"
station_table = "daily_summaries_by_station"
hourly_delay_table = "delays"

# %%
# to do - add schema script

# %%
# verify source file exists
dbutils.fs.ls(source_folder_path)
