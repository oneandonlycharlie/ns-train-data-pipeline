# %%
# create databse for presentation layer 

create_db_sql = '''
    CREATE DATABASE IF NOT EXISTS {presentation_db_name}
'''

create_summary_table_sql = '''
    CREATE TABLE IF NOT EXISTS {presentation_db_name}.{daily_summary_table}
    LOCATION '{presentation_folder_path}/{daily_summary_table}'
'''

create_station_table_sql = '''
    CREATE TABLE IF NOT EXISTS {presentation_db_name}.{station_table}
    LOCATION '{presentation_folder_path}/{station_table}'
'''

# create_hourly_delay_table_sql = '''
#     CREATE TABLE IF NOT EXISTS {presentation_db_name}.{hourly_delay_table}
#     LOCATION '{presentation_folder_path}/{hourly_delay_table}
# '''
