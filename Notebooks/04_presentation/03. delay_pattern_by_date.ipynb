# %%
# %run ../01_setup/storage_config

# %%
# read data 
services_df = spark.table("ns_train_processed.services")
stops_df = spark.table("ns_train_processed.stops")

display(stops_df)

# %% [markdown]
# Select fields:
# 1. hour
# 2. avg_arrival_delay
# 3. avg_departure_delay
# 4. total arrivals
# 5. arrival delay rate
# 6. total departures
# 7. departure delay rate
